# %%
# !python -m pip install bing-image-downloader
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\arjun b\appdata\local\programs\python\python39\lib\site-packages)

# %%
# !mkdir dataset

# %%
from bing_image_downloader import downloader
downloader.download("vietnamies alphabets",limit=50,output_dir='dataset')
# Out:
# [%] Downloading Images to C:\Users\ARJUN B\Desktop\tesseract\dataset\vietnamies alphabets
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://oppidanlibrary.com/wp-content/uploads/2017/05/Vietnamese-Alphabet-Chart.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://4.bp.blogspot.com/-QzoP13wL34E/Wl9MnG0u2OI/AAAAAAAAMl4/YNa7f3XB5NcYrnPKpUDrBIH6i3R07nZEQCK4BGAYYCw/s1600/picture-770313.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://anthroillinois.files.wordpress.com/2011/09/vietnamese-alphabet.gif
# [Error]Invalid image, not saving http://anthroillinois.files.wordpress.com/2011/09/vietnamese-alphabet.gif
#
# [!] Issue getting: http://anthroillinois.files.wordpress.com/2011/09/vietnamese-alphabet.gif
# [!] Error:: Invalid image, not saving http://anthroillinois.files.wordpress.com/2011/09/vietnamese-alphabet.gif
#
# ...
